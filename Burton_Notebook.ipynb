# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import os

from sklearn.model_selection import train_test_split
import sklearn.preprocessing
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix
np.random.seed(123)

import warnings
warnings.filterwarnings("ignore")

from scipy import stats
import re

# %%
df = pd.read_csv('steamspy_3000_games.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    appid                              name  \
# 0         570      570                            Dota 2
# 1         730      730  Counter-Strike: Global Offensive
# 2      578080   578080               PUBG: BATTLEGROUNDS
# 3     1063730  1063730                         New World
# 4     1172470  1172470                      Apex Legends
#
#                           developer        publisher  score_rank  positive  \
# 0                             Valve            Valve         NaN   1587210
# 1  Valve, Hidden Path Entertainment            Valve         NaN   6084096
# 2                     KRAFTON, Inc.    KRAFTON, Inc.         NaN   1214011
# 3                      Amazon Games     Amazon Games         NaN    174544
# 4             Respawn Entertainment  Electronic Arts         NaN    483639
#
#    negative  userscore                      owners  average_forever  \
# 0    330303          0  200,000,000 .. 500,000,000            40447
# ...

# %%
def split_data(df):
    train_validate, test = train_test_split(df, test_size=.2, 
                                        random_state=123)
    train, validate = train_test_split(train_validate, test_size=.3, 
                                   random_state=123)
    return train, validate, test

# %%
train, validate, test = split_data(df)

# %%
sns.pairplot(train)

# %%
plt.hist(data=train, x='median_forever')
plt.show()

# %%
plt.hist(data=train, x='median_2weeks')
plt.show()

# %%
plt.hist(data=train, x='positive')
plt.show()

# %%
plt.hist(data=train, x='negative')
plt.show()

# %%
plt.hist(data=train, x='average_2weeks')
plt.show()

# %%
plt.hist(data=train, x='ccu')
plt.show()

# %%
plt.hist(data=train, x='average_forever')
plt.show()

# %%
def get_median(df):
    sns.scatterplot(data=train, y='average_forever', x='median_forever')
    plt.title('average vs. median')
    plt.show

# %%
get_median(df)

# %%
sns.scatterplot(data=train, y='average_forever', x='median_2weeks')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(data=train, y='average_forever', x='average_2weeks')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(data=train, y='average_forever', x='ccu') # current count updated
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(data=train, y='average_forever', x='negative')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(data=train, y='average_forever', x='positive')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(data=train, y='average_forever', x='name')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
