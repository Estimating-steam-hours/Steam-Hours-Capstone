# %%
import requests
import pandas as pd
import json

# %%
#response = requests.get('https://steamspy.com/api.php?request=top100in2weeks')

# %%
#response_data = response.json()

# %%
#response_data

# %%
#steamspy_df = pd.DataFrame(response_data).T

# %%
#steamspy_df

# %%
#steamspy_df.to_csv('steamspy_top100_2weeks.csv', index=False)

# %%
#long_response1 = requests.get('https://steamspy.com/api.php?request=all&page=0&appdetails')

# %%
#long_data1 = long_response1.json()

# %%
#long_data1

# %%
#steamspy_df1 = pd.DataFrame(long_data1).T
#steamspy_df1

# %%
#long_response2 = requests.get('https://steamspy.com/api.php?request=all&page=1')

# %%
#long_data2 = long_response2.json()

# %%
#steamspy_df2 = pd.DataFrame(long_data2).T
#steamspy_df2

# %%
#long_response3 = requests.get('https://steamspy.com/api.php?request=all&page=2')
#long_data3 = long_response3.json()
#steamspy_df3 = pd.DataFrame(long_data3).T
#steamspy_df3

# %%
#frames = [steamspy_df1, steamspy_df2, steamspy_df3]
#conc = pd.concat(frames)

# %%
#conc.to_csv('steamspy_3000_games.csv')

# %%
df = pd.read_csv('steamspy_3000_games.csv', index_col = 0)

# %%
df
# Out:
#            appid                              name  \
# 570          570                            Dota 2
# 730          730  Counter-Strike: Global Offensive
# 578080    578080               PUBG: BATTLEGROUNDS
# 1063730  1063730                         New World
# 1172470  1172470                      Apex Legends
# ...          ...                               ...
# 933820    933820           Endzone - A World Apart
# 6550        6550   Devil May Cry 3 Special Edition
# 1562420  1562420                        FOREWARNED
# 945490    945490              Little Square Things
# 99700      99700                          NightSky
#
#                                 developer  \
# 570                                 Valve
# 730      Valve, Hidden Path Entertainment
# 578080                      KRAFTON, Inc.
# 1063730                      Amazon Games
# 1172470             Respawn Entertainment
# ...                                   ...
# 933820                  Gentlymad Studios
# 6550                     CAPCOM Co., Ltd.
# 1562420                   Dreambyte Games
# 945490                             G.Reed
# 99700                       Nicalis, Inc.
#
#                                     publisher  score_rank  positive  negative  \
# 570                                     Valve         NaN   1587210    330303
# 730                                     Valve         NaN   6084096    801021
# 578080                          KRAFTON, Inc.         NaN   1214011    917768
# 1063730                          Amazon Games         NaN    174544     75536
# 1172470                       Electronic Arts         NaN    483639     93045
# ...                                       ...         ...       ...       ...
# 933820   Assemble Entertainment, WhisperGames         NaN      5951      1661
# 6550                                   Capcom         NaN      2077      1364
# 1562420                       Dreambyte Games         NaN      3650       347
# 945490                            Team3Studio         NaN        51         9
# 99700                           Nicalis, Inc.         NaN       828       116
#
#          userscore                      owners  average_forever  \
# 570              0  200,000,000 .. 500,000,000            40447
# 730              0   50,000,000 .. 100,000,000            29608
# 578080           0   50,000,000 .. 100,000,000            22856
# 1063730          0   50,000,000 .. 100,000,000             8257
# 1172470          0   50,000,000 .. 100,000,000             6705
# ...            ...                         ...              ...
# 933820           0          200,000 .. 500,000              617
# 6550             0          200,000 .. 500,000             1890
# 1562420          0          200,000 .. 500,000              258
# 945490           0          200,000 .. 500,000                0
# 99700            0          200,000 .. 500,000              104
#
#          average_2weeks  median_forever  median_2weeks  price  initialprice  \
# 570                1560             976           1084      0             0
# 730                 771            6381            271      0             0
# 578080              648            6688            189      0             0
# 1063730            1454            3567           1311   3999          3999
# 1172470             746             605            362      0             0
# ...                 ...             ...            ...    ...           ...
# 933820               71             240             89    749          2999
# 6550                  0              61              0   1999          1999
# 1562420              21             177             21   1299          1299
# 945490                0               0              0      0             0
# 99700                 0              75              0    999           999
#
#          discount     ccu
# 570             0  543171
# 730             0  938203
# 578080          0  324204
# 1063730         0   30922
# 1172470         0  292023
# ...           ...     ...
# 933820         75     339
# 6550            0      13
# 1562420         0     290
# 945490          0       0
# 99700           0       2
#
# [3000 rows x 17 columns]

# %%
app_list = list(df.appid)

# %%
#app_list

# %%
response = requests.get(f'https://steamspy.com/api.php?request=appdetails&appid=730') #{app_list[i]}')
response_data = response.json()
response_df = pd.DataFrame(response_data)

# %%
response_data['tags'].keys()
# Out:
# dict_keys(['FPS', 'Shooter', 'Multiplayer', 'Competitive', 'Action', 'Team-Based', 'e-sports', 'Tactical', 'First-Person', 'PvP', 'Online Co-Op', 'Co-op', 'Strategy', 'Military', 'War', 'Difficult', 'Trading', 'Realistic', 'Fast-Paced', 'Moddable'])

# %%
response_df
# Out:
#               appid                              name  \
# Action          730  Counter-Strike: Global Offensive
# Co-op           730  Counter-Strike: Global Offensive
# Competitive     730  Counter-Strike: Global Offensive
# Difficult       730  Counter-Strike: Global Offensive
# FPS             730  Counter-Strike: Global Offensive
# Fast-Paced      730  Counter-Strike: Global Offensive
# First-Person    730  Counter-Strike: Global Offensive
# Military        730  Counter-Strike: Global Offensive
# Moddable        730  Counter-Strike: Global Offensive
# Multiplayer     730  Counter-Strike: Global Offensive
# Online Co-Op    730  Counter-Strike: Global Offensive
# PvP             730  Counter-Strike: Global Offensive
# Realistic       730  Counter-Strike: Global Offensive
# Shooter         730  Counter-Strike: Global Offensive
# Strategy        730  Counter-Strike: Global Offensive
# Tactical        730  Counter-Strike: Global Offensive
# Team-Based      730  Counter-Strike: Global Offensive
# Trading         730  Counter-Strike: Global Offensive
# War             730  Counter-Strike: Global Offensive
# e-sports        730  Counter-Strike: Global Offensive
#
#                                      developer publisher score_rank  positive  \
# Action        Valve, Hidden Path Entertainment     Valve              6084096
# Co-op         Valve, Hidden Path Entertainment     Valve              6084096
# Competitive   Valve, Hidden Path Entertainment     Valve              6084096
# Difficult     Valve, Hidden Path Entertainment     Valve              6084096
# FPS           Valve, Hidden Path Entertainment     Valve              6084096
# Fast-Paced    Valve, Hidden Path Entertainment     Valve              6084096
# First-Person  Valve, Hidden Path Entertainment     Valve              6084096
# FPS                     0        0  938203
# Fast-Paced              0        0  938203
# First-Person            0        0  938203
# Military                0        0  938203
# Moddable                0        0  938203
# Multiplayer             0        0  938203
# Online Co-Op            0        0  938203
# PvP                     0        0  938203
# Realistic               0        0  938203
# Shooter                 0        0  938203
# Strategy                0        0  938203
# Tactical                0        0  938203
# Team-Based              0        0  938203
# Trading                 0        0  938203
# War                     0        0  938203
# e-sports                0        0  938203
#
#                                                       languages  \
# Action        English, Czech, Danish, Dutch, Finnish, French...
# Co-op         English, Czech, Danish, Dutch, Finnish, French...
# Competitive   English, Czech, Danish, Dutch, Finnish, French...
# Difficult     English, Czech, Danish, Dutch, Finnish, French...
# FPS           English, Czech, Danish, Dutch, Finnish, French...
# Fast-Paced    English, Czech, Danish, Dutch, Finnish, French...
# First-Person  English, Czech, Danish, Dutch, Finnish, French...
# Military      English, Czech, Danish, Dutch, Finnish, French...
# Moddable      English, Czech, Danish, Dutch, Finnish, French...
# Multiplayer   English, Czech, Danish, Dutch, Finnish, French...
# Online Co-Op  English, Czech, Danish, Dutch, Finnish, French...
# PvP           English, Czech, Danish, Dutch, Finnish, French...
# Realistic     English, Czech, Danish, Dutch, Finnish, French...
# Shooter       English, Czech, Danish, Dutch, Finnish, French...
# Strategy      English, Czech, Danish, Dutch, Finnish, French...
# Tactical      English, Czech, Danish, Dutch, Finnish, French...
# Team-Based    English, Czech, Danish, Dutch, Finnish, French...
# Trading       English, Czech, Danish, Dutch, Finnish, French...
# War           English, Czech, Danish, Dutch, Finnish, French...
# e-sports      English, Czech, Danish, Dutch, Finnish, French...
#
#                              genre   tags
# Action        Action, Free to Play  46425
# Co-op         Action, Free to Play  29582
# Competitive   Action, Free to Play  51960
# Difficult     Action, Free to Play  25510
# FPS           Action, Free to Play  88503
# Fast-Paced    Action, Free to Play  24863
# First-Person  Action, Free to Play  38425
# Military      Action, Free to Play  28088
# Moddable      Action, Free to Play   6167
# Multiplayer   Action, Free to Play  60678
# Online Co-Op  Action, Free to Play  33163
# PvP           Action, Free to Play  33513
# Realistic     Action, Free to Play  24916
# Shooter       Action, Free to Play  63589
# Strategy      Action, Free to Play  29457
# Tactical      Action, Free to Play  40421
# Team-Based    Action, Free to Play  45347
# Trading       Action, Free to Play  25083
# War           Action, Free to Play  27469
# e-sports      Action, Free to Play  42313

# %%
print(response_data['appid'])
print(response_data['genre'])
#print(response_data['tags'])
# Out:
# 730
# Action, Free to Play

# %%
new_df = pd.DataFrame([[]])

# %%
new_df['appid'] = response_data['appid']

# %%
new_df['genre'] = response_data['genre']

# %%
new_df
# Out:
#    appid                 genre
# 0    730  Action, Free to Play

# %%
new_df = pd.DataFrame([[]])
for i in app_list:
    response = requests.get(f'https://steamspy.com/api.php?request=appdetails&appid={app_list[i]}')
    response_data = response.json()
