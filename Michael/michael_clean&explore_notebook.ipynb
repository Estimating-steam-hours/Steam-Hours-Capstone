# %%
import requests
import pandas as pd
import json

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from math import sqrt

from scipy import stats
from pydataset import data
import Wrangle as w

# %%
df = pd.read_csv('final_steamspy_3000_games.csv', index_col = 0)

# %%
df
# Out:
#         appid                              name  \
# 0         570                            Dota 2
# 1         730  Counter-Strike: Global Offensive
# 2      578080               PUBG: BATTLEGROUNDS
# 3     1063730                         New World
# 4     1172470                      Apex Legends
# ...       ...                               ...
# 2995   933820           Endzone - A World Apart
# 2996     6550   Devil May Cry 3 Special Edition
# 2997  1562420                        FOREWARNED
# 2998   945490              Little Square Things
# 2999    99700                          NightSky
#
#                              developer                             publisher  \
# 0                                Valve                                 Valve
# 1     Valve, Hidden Path Entertainment                                 Valve
# 2                        KRAFTON, Inc.                         KRAFTON, Inc.
# 3                         Amazon Games                          Amazon Games
# 4                Respawn Entertainment                       Electronic Arts
# ...                                ...                                   ...
# 2995                 Gentlymad Studios  Assemble Entertainment, WhisperGames
# 2996                  CAPCOM Co., Ltd.                                Capcom
# 2997                   Dreambyte Games                       Dreambyte Games
# 2998                            G.Reed                           Team3Studio
# 2999                     Nicalis, Inc.                         Nicalis, Inc.
#
#       score_rank  positive  negative  userscore                      owners  \
# 0            NaN   1587210    330303          0  200,000,000 .. 500,000,000
# 1            NaN   6084096    801021          0   50,000,000 .. 100,000,000
# 2            NaN   1214011    917768          0   50,000,000 .. 100,000,000
# 3            NaN    174544     75536          0   50,000,000 .. 100,000,000
# 4            NaN    483639     93045          0   50,000,000 .. 100,000,000
# ...          ...       ...       ...        ...                         ...
# 2995         NaN      5951      1661          0          200,000 .. 500,000
# 2996         NaN      2077      1364          0          200,000 .. 500,000
# 2997         NaN      3650       347          0          200,000 .. 500,000
# 2998         NaN        51         9          0          200,000 .. 500,000
# 2999         NaN       828       116          0          200,000 .. 500,000
#
#       average_forever  average_2weeks  median_forever  median_2weeks  price  \
# 0               40447            1560             976           1084      0
# 1               29608             771            6381            271      0
# 2               22856             648            6688            189      0
# 3                8257            1454            3567           1311   3999
# 4                6705             746             605            362      0
# ...               ...             ...             ...            ...    ...
# 2995              617              71             240             89    749
# 2996             1890               0              61              0   1999
# 2997              258              21             177             21   1299
# 2998                0               0               0              0      0
# 2999              104               0              75              0    999
#
#       initialprice  discount     ccu  appid.1  \
# 0                0         0  543171      570
# 1                0         0  938203      730
# 2                0         0  324204   578080
# 3             3999         0   30922  1063730
# 4                0         0  292023  1172470
# ...            ...       ...     ...      ...
# 2995          2999        75     339   933820
# 2996          1999         0      13     6550
# 2997          1299         0     290  1562420
# 2998             0         0       0   945490
# 2999           999         0       2    99700
#
#                                                                                            tags  \
# 0     ['Free to Play', 'MOBA', 'Multiplayer', 'Strategy', 'e-sports', 'Team-Based', 'Competi...
# 1     ['FPS', 'Shooter', 'Multiplayer', 'Competitive', 'Action', 'Team-Based', 'e-sports', '...
# 2     ['Survival', 'Shooter', 'Battle Royale', 'Multiplayer', 'FPS', 'PvP', 'Third-Person Sh...
# 3     ['Massively Multiplayer', 'Open World', 'MMORPG', 'RPG', 'Adventure', 'Action', 'PvP',...
# 4     ['Free to Play', 'Multiplayer', 'Battle Royale', 'Shooter', 'FPS', 'First-Person', 'Pv...
# ...                                                                                         ...
# 2995  ['City Builder', 'Strategy', 'Survival', 'Post-apocalyptic', 'Simulation', 'Base-Build...
# 2996  ['Action', 'Hack and Slash', 'Great Soundtrack', 'Spectacle fighter', 'Stylized', 'Cha...
# 2997  ['Horror', 'Online Co-Op', 'Survival Horror', 'Co-op', 'Multiplayer', 'Psychological H...
# 2998  ['Early Access', 'Indie', 'Strategy', 'Puzzle', 'Sokoban', 'Retro', 'Free to Play', 'T...
# 2999  ['Puzzle-Platformer', 'Indie', 'Platformer', 'Casual', 'Puzzle', 'Physics', 'Atmospher...
#
#                                                        genre
# 0                             Action, Free to Play, Strategy
# 1                                       Action, Free to Play
# 2     Action, Adventure, Free to Play, Massively Multiplayer
# 3              Action, Adventure, Massively Multiplayer, RPG
# 4                            Action, Adventure, Free to Play
# ...                                                      ...
# 2995                             Indie, Simulation, Strategy
# 2996                                                  Action
# 2997                  Action, Adventure, Indie, Early Access
# 2998                                         Indie, Strategy
# 2999                                 Casual, Indie, Strategy
#
# [3000 rows x 20 columns]

# %%
df = w.clean_steamspy(df)
# Out:
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Publisher_{x}'] = df.publisher.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Developer_{x}'] = df.developer.str.contains(x,regex = False)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)
# /Users/michaelmesa/codeup-data-science/Steam-Hours-Capstone/Michael/Wrangle.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'Genre_{x}'] = df.genre.str.contains(x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2846 entries, 0 to 2999
# Columns: 104 entries, appid to Genre_Early Access
# dtypes: category(1), float64(4), int64(8), object(91)
# memory usage: 2.3+ MB

# %%
df.average_2weeks.value_counts()
# Out:
# 0.000000     1666
# 0.016667       44
# 0.033333       17
# 0.100000       15
# 0.083333       12
#              ...
# 19.166667       1
# 4.583333        1
# 6.866667        1
# 7.266667        1
# 10.983333       1
# Name: average_2weeks, Length: 591, dtype: int64

# %%
df.average_forever.value_counts()
# Out:
# 2.800000     9
# 3.883333     9
# 3.633333     8
# 4.183333     8
# 3.516667     8
#             ..
# 22.416667    1
# 27.516667    1
# 57.266667    1
# 22.983333    1
# 54.383333    1
# Name: average_forever, Length: 1562, dtype: int64

# %%
#df.discount.value_counts()

# %%
#df.score_rank.value_counts()

# %%
#df[df['average_2weeks']==0]

# %%
#df[df['average_2weeks']!=0]

# %%
df = df[df['average_forever']!=0]

# %%
#df.info()

# %%
#df[df.publisher.isnull() == True]

# %%
#df[df.genre.isnull() == True]

# %%
#df.dropna()

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2846 entries, 0 to 2999
# Columns: 104 entries, appid to Genre_Early Access
# dtypes: category(1), float64(4), int64(8), object(91)
# memory usage: 2.3+ MB

# %%
train, validate, test = w.my_train_test_split(df)

# %%
def get_tree(train_x, validate_x, train_y, validate_y):
    
    '''get decision tree accuracy on train and validate'''
    #create classifier then fit
    tree = DecisionTreeClassifier(max_depth=5, random_state=123)
    tree = tree.fit(train_x, train_y)

    print(f"Accuracy of Decision Tree on train data is {tree.score(train_x, train_y)}")
    print(f"Accuracy of Decision Tree on validate data is {tree.score(validate_x, validate_y)}")
    
#get_tree(train_x, validate_x, train_y, validate_y)


# ### rf

# In[24]:


def get_rf(train_x, validate_x, train_y, validate_y):

    '''get rf accuracy on train and validate'''
    #create classifier and fit
    rf = RandomForestClassifier(max_depth=5, random_state=123)
    rf = rf.fit(train_x, train_y)

    print(f"Accuracy of Random Forest on train data is {rf.score(train_x, train_y)}")
    print(f"Accuracy of Random Forest on validate data is {rf.score(validate_x, validate_y)}")


# ### regression

# In[25]:


def get_reg(train_x, validate_x, train_y, validate_y):

    '''get reg accuracy on train and validate'''
    #create classifier and fit
    logit = LogisticRegression(solver='liblinear')
    logit = logit.fit(train_x, train_y)

    print(f"Accuracy of Logistic Regression on train is {logit.score(train_x, train_y)}")
    print(f"Accuracy of Logistic Regression on validate is {logit.score(validate_x, validate_y)}")


# ### knn

# In[26]:


def get_knn(train_x, validate_x, train_y, validate_y):
    
    '''get knn accuracy on train and validate'''
    knn = KNeighborsClassifier(n_neighbors=5, weights='uniform')
    knn = knn.fit(train_x, train_y)

    # print results
    print(f"Accuracy of KNN on train is {knn.score(train_x, train_y)}")
    print(f"Accuracy of KNN on validate is {knn.score(validate_x, validate_y)}")

# %%
train.head(3)
# Out:
#        appid                         name                    developer  \
# 689   216150                   MapleStory                        Nexon
# 1622  332310                  LEGO Worlds  TT_Games,_Traveller's_Tales
# 2878  601050  Attack on Titan 2 - A.O.T.2   KOEI_TECMO_GAMES_CO.,_LTD.
#
#                                    publisher  positive  negative  \
# 689                       Nexon_America_Inc.      7110      3025
# 1622  Warner_Bros._Interactive_Entertainment     11319      3189
# 2878              KOEI_TECMO_GAMES_CO.,_LTD.      4854       403
#
#                       owners  average_forever  average_2weeks  median_forever  \
# 689   1,000,000 .. 2,000,000        11.933333        4.216667        2.350000
# 1622    500,000 .. 1,000,000        18.233333        0.483333        4.150000
# 2878      200,000 .. 500,000        14.383333        0.000000       14.483333
#
#       ...  Genre_Software Training  Genre_ Game Development  \
# 689   ...                    False                    False
# 1622  ...                    False                    False
# 2878  ...                    False                    False
#
#       Genre_ Audio Production  Genre_ Web Publishing  \
# 689                     False                  False
# 1622                    False                  False
# 2878                    False                  False
#
#       Genre_Design & Illustration  Genre_Game Development Genre_ Movie  \
# 689                         False                   False        False
# 1622                        False                   False        False
# 2878                        False                   False        False
#
#      Genre_ Education Genre_ Software Training Genre_Early Access
# 689             False                    False              False
# 1622            False                    False              False
# 2878            False                    False              False
#
# [3 rows x 104 columns]

# %%
model_df = df.drop(columns=['appid','appid.1','name','developer', 'publisher','positive','negative','average_forever','average_2weeks','owners','median_forever', 'median_2weeks','price','discount','initialprice','ccu','tags','genre', 'Publisher_'])

# %%
model_df.head(3)
# Out:
#   binned_hours Publisher_Valve Publisher_KRAFTON Publisher__Inc.  \
# 0  most_played            True             False           False
# 1  most_played            True             False           False
# 2  most_played           False              True            True
#
#   Publisher_Rockstar_Games Publisher_Facepunch_Studios Publisher_Ubisoft  \
# 0                    False                       False             False
# 1                    False                       False             False
# 2                    False                       False             False
#
#   Publisher_Psyonix_LLC Publisher_Bohemia_Interactive Publisher_SEGA  ...  \
# 0                 False                         False          False  ...
# 1                 False                         False          False  ...
# 2                 False                         False          False  ...
#
#   Genre_Software Training Genre_ Game Development Genre_ Audio Production  \
# 0                   False                   False                   False
# 1                   False                   False                   False
# 2                   False                   False                   False
#
#   Genre_ Web Publishing Genre_Design & Illustration Genre_Game Development  \
# 0                 False                       False                  False
# 1                 False                       False                  False
# 2                 False                       False                  False
#
#   Genre_ Movie Genre_ Education Genre_ Software Training Genre_Early Access
# 0        False            False                    False              False
# 1        False            False                    False              False
# 2        False            False                    False              False
#
# [3 rows x 85 columns]

# %%
model_df
# Out:
#            binned_hours Publisher_Valve Publisher_KRAFTON Publisher__Inc.  \
# 0           most_played            True             False           False
# 1           most_played            True             False           False
# 2           most_played           False              True            True
# 3        heavily_played           False             False           False
# 4        heavily_played           False             False           False
# ...                 ...             ...               ...             ...
# 2994  moderately_played           False             False           False
# 2995  moderately_played           False             False           False
# 2996  moderately_played           False             False           False
# 2997  moderately_played           False             False           False
# 2999  moderately_played           False             False            True
#
#      Publisher_Rockstar_Games Publisher_Facepunch_Studios Publisher_Ubisoft  \
# 0                       False                       False             False
# 1                       False                       False             False
# 2                       False                       False             False
# 3                       False                       False             False
# 4                       False                       False             False
# ...                       ...                         ...               ...
# 2994                    False                       False             False
# 2995                    False                       False             False
# 2996                    False                       False             False
# 2997                    False                       False             False
# 2999                    False                       False             False
#
#      Publisher_Psyonix_LLC Publisher_Bohemia_Interactive Publisher_SEGA  ...  \
# 0                    False                         False          False  ...
# 1                    False                         False          False  ...
# 2                    False                         False          False  ...
# 3                    False                         False          False  ...
# 4                    False                         False          False  ...
# ...                    ...                           ...            ...  ...
# 2994                 False                         False          False  ...
# 2995                 False                         False          False  ...
# 2996                 False                         False          False  ...
# 2997                 False                         False          False  ...
# 2999                 False                         False          False  ...
#
#      Genre_Software Training Genre_ Game Development Genre_ Audio Production  \
# 0                      False                   False                   False
# 1                      False                   False                   False
# 2                      False                   False                   False
# 3                      False                   False                   False
# 4                      False                   False                   False
# ...                      ...                     ...                     ...
# 2994                   False                   False                   False
# 2995                   False                   False                   False
# 2996                   False                   False                   False
# 2997                   False                   False                   False
# 2999                   False                   False                   False
#
#      Genre_ Web Publishing Genre_Design & Illustration Genre_Game Development  \
# 0                    False                       False                  False
# 1                    False                       False                  False
# 2                    False                       False                  False
# 3                    False                       False                  False
# 4                    False                       False                  False
# ...                    ...                         ...                    ...
# 2994                 False                       False                  False
# 2995                 False                       False                  False
# 2996                 False                       False                  False
# 2997                 False                       False                  False
# 2999                 False                       False                  False
#
#      Genre_ Movie Genre_ Education Genre_ Software Training Genre_Early Access
# 0           False            False                    False              False
# 1           False            False                    False              False
# 2           False            False                    False              False
# 3           False            False                    False              False
# 4           False            False                    False              False
# ...           ...              ...                      ...                ...
# 2994        False            False                    False              False
# 2995        False            False                    False              False
# 2996        False            False                    False              False
# 2997        False            False                    False               True
# 2999        False            False                    False              False
#
# [2846 rows x 85 columns]

# %%
model_df.head(3)
# Out:
#   binned_hours Publisher_Valve Publisher_KRAFTON Publisher__Inc.  \
# 0  most_played            True             False           False
# 1  most_played            True             False           False
# 2  most_played           False              True            True
#
#   Publisher_Rockstar_Games Publisher_Facepunch_Studios Publisher_Ubisoft  \
# 0                    False                       False             False
# 1                    False                       False             False
# 2                    False                       False             False
#
#   Publisher_Psyonix_LLC Publisher_Bohemia_Interactive Publisher_SEGA  ...  \
# 0                 False                         False          False  ...
# 1                 False                         False          False  ...
# 2                 False                         False          False  ...
#
#   Genre_Software Training Genre_ Game Development Genre_ Audio Production  \
# 0                   False                   False                   False
# 1                   False                   False                   False
# 2                   False                   False                   False
#
#   Genre_ Web Publishing Genre_Design & Illustration Genre_Game Development  \
# 0                 False                       False                  False
# 1                 False                       False                  False
# 2                 False                       False                  False
#
#   Genre_ Movie Genre_ Education Genre_ Software Training Genre_Early Access
# 0        False            False                    False              False
# 1        False            False                    False              False
# 2        False            False                    False              False
#
# [3 rows x 85 columns]
